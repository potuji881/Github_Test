# %%
import numpy as np
import matplotlib.pyplot as plt

# generate data
x = np.random.rand(10)
y = np.random.rand(10)

plt.scatter(x,y)

ax.set_title('first scatter plot')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a5e14980021> in <module>()
#       8 # fig = plt.figure()
#       9
# ---> 10 ax = fig.add_subplot(1,1,1)
#      11
#      12 ax.scatter(x,y)
#
# NameError: name 'fig' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)

plt.title("scatterplot")
plt.xlabel("x")
plt.ylabel("y")

plt.show()
